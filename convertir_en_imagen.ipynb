# %% [markdown]
# <a href="https://colab.research.google.com/github/gsepulv1/20212-ST0245/blob/main/convertir_en_imagen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-1877054c-de72-485e-8c89-36caf3197b80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1877054c-de72-485e-8c89-36caf3197b80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 11-0.csv to 11-0 (2).csv

# %%
dfe=pd.read_csv("11-0.csv", sep=',',header=None)

# %%
dfe
# Out:
#      0    1    2    3    4    5    6    ...  420  421  422  423  424  425  426
# 0    139  139  139  140  140  140  141  ...   21   27   24   14   14   19   24
# 1    139  139  140  140  141  141  141  ...   24   30   33   31   52   56   62
# 2    140  140  141  141  141  142  142  ...   30   36   43   50   64   68   71
# 3    141  141  142  142  143  143  143  ...   39   45   52   61   66   66   67
# 4    143  143  143  143  144  144  145  ...   50   59   63   67   64   63   61
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 308   32   29   26   28   32   33   31  ...    9    9   19   35   44   49   51
# 309   31   31   32   35   37   34   28  ...   14   14   28   56   72   76   76
# 310   33   33   34   35   37   37   35  ...   22   11   17   47   87   92   94
# 311   35   31   26   22   22   27   34  ...   28   12   14   44   74   81   85
# 312   34   31   31   33   31   28   31  ...   32   25   26   32   43   49   53
#
# ...

# %%
matriz=np.matrix(dfe)

# %%
matriz
# Out:
# matrix([[139, 139, 139, ...,  14,  19,  24],
#         [139, 139, 140, ...,  52,  56,  62],
#         [140, 140, 141, ...,  64,  68,  71],
#         ...,
#         [ 33,  33,  34, ...,  87,  92,  94],
#         [ 35,  31,  26, ...,  74,  81,  85],
#         [ 34,  31,  31, ...,  43,  49,  53]])

# %%
plt.gray()
plt.imshow(matriz)
